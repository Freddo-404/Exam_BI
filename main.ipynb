# %%
import pandas as pd
import numpy as np

df1 = pd.read_excel("Data\Afbrudt_institution.xlsx")
df2 = pd.read_excel("Data\Afbrudte uddannelse .xlsx")
df3 = pd.read_excel("Data\Fuldførte institution .xlsx")
df4 = pd.read_excel("Data\Fuldførte uddannelse .xlsx")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\A'
# <>:5: SyntaxWarning: invalid escape sequence '\A'
# <>:6: SyntaxWarning: invalid escape sequence '\F'
# <>:7: SyntaxWarning: invalid escape sequence '\F'
# <>:4: SyntaxWarning: invalid escape sequence '\A'
# <>:5: SyntaxWarning: invalid escape sequence '\A'
# <>:6: SyntaxWarning: invalid escape sequence '\F'
# <>:7: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\ferdi\AppData\Local\Temp\ipykernel_34632\2037392247.py:4: SyntaxWarning: invalid escape sequence '\A'
#   df1 = pd.read_excel("Data\Afbrudt_institution.xlsx")
# C:\Users\ferdi\AppData\Local\Temp\ipykernel_34632\2037392247.py:5: SyntaxWarning: invalid escape sequence '\A'
#   df2 = pd.read_excel("Data\Afbrudte uddannelse .xlsx")
# C:\Users\ferdi\AppData\Local\Temp\ipykernel_34632\2037392247.py:6: SyntaxWarning: invalid escape sequence '\F'
#   df3 = pd.read_excel("Data\Fuldførte institution .xlsx")
# ...

# %%
df2.head()
# Out:
#                                 År                              Unnamed: 1  \
# 0                       Uddannelse                                  MGRPTX
# 1  Erhvervsakademiuddannelser (EA)                                   Total
# 2  Erhvervsakademiuddannelser (EA)  Bio- og laboratorietekniske område, EA
# 3  Erhvervsakademiuddannelser (EA)                Designfaglige område, EA
# 4  Erhvervsakademiuddannelser (EA)                   It-faglige område, EA
#
#   Unnamed: 2   2015   2016   2017   2018   2019   2020   2021   2022   2023  \
# 0     UGRPTX  Antal  Antal  Antal  Antal  Antal  Antal  Antal  Antal  Antal
# 1        NaN   4275   4073   3880   3672   3674   3547   3703   4125   2970
# 2      Total    322    242    235    266    288    247    244    312    185
# 3      Total    162    156    145    137    133     96    116    126    107
# 4      Total   1278   1034   1001    901    847    802    801    841    636
#
#     2024
# 0  Antal
# 1   3552
# 2    239
# 3    107
# ...

# %%
df2.info()
df2.describe(include='all')
df2.columns
df2.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   År          109 non-null    object
#  1   Unnamed: 1  108 non-null    object
#  2   Unnamed: 2  104 non-null    object
#  3   2015        108 non-null    object
#  4   2016        106 non-null    object
#  5   2017        107 non-null    object
#  6   2018        107 non-null    object
#  7   2019        107 non-null    object
#  8   2020        107 non-null    object
#  9   2021        107 non-null    object
#  10  2022        108 non-null    object
#  11  2023        106 non-null    object
#  12  2024        106 non-null    object
# dtypes: object(13)
# memory usage: 11.2+ KB
# År            0
# Unnamed: 1    1
# Unnamed: 2    5
# 2015          1
# 2016          3
# 2017          2
# 2018          2
# 2019          2
# 2020          2
# 2021          2
# 2022          1
# ...

# %%
df2.replace("Total", np.nan, inplace=True)
df2.replace(np.nan, '',inplace=True)

# %%
df2.head(100)
# Out:
#                                  År                              Unnamed: 1  \
# 0                        Uddannelse                                  MGRPTX
# 1   Erhvervsakademiuddannelser (EA)
# 2   Erhvervsakademiuddannelser (EA)  Bio- og laboratorietekniske område, EA
# 3   Erhvervsakademiuddannelser (EA)                Designfaglige område, EA
# 4   Erhvervsakademiuddannelser (EA)                   It-faglige område, EA
# ..                              ...                                     ...
# 95              Kandidatuddannelser                        Teknik, kandidat
# 96              Kandidatuddannelser                        Teknik, kandidat
# 97              Kandidatuddannelser                        Teknik, kandidat
# 98              Kandidatuddannelser                         Natur, kandidat
# 99              Kandidatuddannelser                         Natur, kandidat
#
#                  Unnamed: 2   2015   2016   2017   2018   2019   2020   2021  \
# ...

# %%
df2.rename(columns={'Unnamed: 1': 'FagLinjer', 'Unnamed: 2': 'FagRetning', 'År': 'Uddannelse'}, inplace=True)

# %%
df2.drop(index=0, inplace=True)

# %%
df2.head(100)
# Out:
#                           Uddannelse                               FagLinjer  \
# 1    Erhvervsakademiuddannelser (EA)
# 2    Erhvervsakademiuddannelser (EA)  Bio- og laboratorietekniske område, EA
# 3    Erhvervsakademiuddannelser (EA)                Designfaglige område, EA
# 4    Erhvervsakademiuddannelser (EA)                   It-faglige område, EA
# 5    Erhvervsakademiuddannelser (EA)              Samfundsfaglige område, EA
# ..                               ...                                     ...
# 96               Kandidatuddannelser                        Teknik, kandidat
# 97               Kandidatuddannelser                        Teknik, kandidat
# 98               Kandidatuddannelser                         Natur, kandidat
# 99               Kandidatuddannelser                         Natur, kandidat
# 100              Kandidatuddannelser                         Natur, kandidat
#
#                   FagRetning  2015  2016  2017  2018  2019  2020  2021  2022  \
# ...

# %%
df2.replace(r'^\s*$', np.nan, regex=True, inplace=True)
df2.dropna(how='any', inplace=True)
df2["Type"] = "Afbrudt"
# Out:
# C:\Users\ferdi\AppData\Local\Temp\ipykernel_34632\1396757561.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
df2.head(100)
# Out:
#                 Uddannelse                         FagLinjer  \
# 10   Professionsbachelorer  Økonomisk/merkantil, prof. bach.
# 11   Professionsbachelorer  Økonomisk/merkantil, prof. bach.
# 13   Professionsbachelorer               Teknik, prof. bach.
# 14   Professionsbachelorer               Teknik, prof. bach.
# 15   Professionsbachelorer               Teknik, prof. bach.
# ..                     ...                               ...
# 101    Kandidatuddannelser                   Natur, kandidat
# 103    Kandidatuddannelser                 Sundhed, kandidat
# 104    Kandidatuddannelser                 Sundhed, kandidat
# 106    Kandidatuddannelser                 Sundhed, kandidat
# 107    Kandidatuddannelser                 Sundhed, kandidat
#
#                             FagRetning    2015    2016    2017    2018  \
# 10   Marketing og ledelse, prof. bach.   262.0   270.0   289.0   267.0
# 11          Økonomi og IT, prof. bach.   423.0   427.0   483.0   463.0
# ...

# %%
df2.to_excel("Data\Afbrudte uddannelse_cleaned.xlsx", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\ferdi\AppData\Local\Temp\ipykernel_34632\882006165.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df2.to_excel("Data\Afbrudte uddannelse_cleaned.xlsx", index=False)

# %% [markdown]
# Df4

# %%
df4.head()
# Out:
#                                 År                              Unnamed: 1  \
# 0                       Uddannelse                                  MGRPTX
# 1  Erhvervsakademiuddannelser (EA)                                   Total
# 2  Erhvervsakademiuddannelser (EA)  Bio- og laboratorietekniske område, EA
# 3  Erhvervsakademiuddannelser (EA)                Designfaglige område, EA
# 4  Erhvervsakademiuddannelser (EA)                   It-faglige område, EA
#
#   Unnamed: 2   2015   2016   2017   2018   2019   2020   2021   2022   2023  \
# 0     UGRPTX  Antal  Antal  Antal  Antal  Antal  Antal  Antal  Antal  Antal
# 1        NaN   7945   8840   8822   8440   8309   7776   7894   8358   8844
# 2      Total    589    661    591    581    607    519    494    517    589
# 3      Total    798    806    716    692    667    596    623    606    609
# 4      Total   1767   2103   1926   1758   1714   1654   1635   1681   1950
#
#     2024
# 0  Antal
# 1   7294
# 2    557
# 3    574
# ...

# %%
df4.info()
df4.describe(include='all')
df4.columns
df4.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   År          115 non-null    object
#  1   Unnamed: 1  114 non-null    object
#  2   Unnamed: 2  110 non-null    object
#  3   2015        111 non-null    object
#  4   2016        113 non-null    object
#  5   2017        113 non-null    object
#  6   2018        113 non-null    object
#  7   2019        113 non-null    object
#  8   2020        113 non-null    object
#  9   2021        113 non-null    object
#  10  2022        113 non-null    object
#  11  2023        114 non-null    object
#  12  2024        114 non-null    object
# dtypes: object(13)
# memory usage: 11.8+ KB
# År            0
# Unnamed: 1    1
# Unnamed: 2    5
# 2015          4
# 2016          2
# 2017          2
# 2018          2
# 2019          2
# 2020          2
# 2021          2
# 2022          2
# ...

# %%
df4.replace("Total", np.nan, inplace=True)
df4.replace(np.nan, '',inplace=True)

# %%
df4.rename(columns={'Unnamed: 1': 'FagLinjer', 'Unnamed: 2': 'FagRetning', 'År': 'Uddannelse'}, inplace=True)

# %%
df4.drop(index=0, inplace=True)

# %%
df4.replace(r'^\s*$', np.nan, regex=True, inplace=True)
df4.dropna(how='any', inplace=True)
df4["Type"] = "Fuldført"
# Out:
# C:\Users\ferdi\AppData\Local\Temp\ipykernel_34632\3152647252.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df4.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
df4.head(100)
# Out:
#                 Uddannelse                         FagLinjer  \
# 11   Professionsbachelorer  Økonomisk/merkantil, prof. bach.
# 12   Professionsbachelorer  Økonomisk/merkantil, prof. bach.
# 14   Professionsbachelorer               Teknik, prof. bach.
# 15   Professionsbachelorer               Teknik, prof. bach.
# 16   Professionsbachelorer               Teknik, prof. bach.
# ..                     ...                               ...
# 109    Kandidatuddannelser                 Sundhed, kandidat
# 110    Kandidatuddannelser                 Sundhed, kandidat
# 111    Kandidatuddannelser                 Sundhed, kandidat
# 112    Kandidatuddannelser                 Sundhed, kandidat
# 113    Kandidatuddannelser                 Sundhed, kandidat
#
#                             FagRetning    2015    2016    2017    2018  \
# 11   Marketing og ledelse, prof. bach.   618.0   608.0   715.0   815.0
# 12          Økonomi og IT, prof. bach.  1091.0  1183.0  1320.0  1449.0
# ...

# %%
df4.to_excel("Data\Fuldførte_uddannelse_cleaned.xlsx", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\ferdi\AppData\Local\Temp\ipykernel_34632\548814869.py:1: SyntaxWarning: invalid escape sequence '\F'
#   df4.to_excel("Data\Fuldførte_uddannelse_cleaned.xlsx", index=False)

# %%
Uddannelse_combined = pd.concat([df2, df4], ignore_index=True)

# %%
Uddannelse_combined.to_excel(r"Data\Uddannelse_combined.xlsx", index=False)
